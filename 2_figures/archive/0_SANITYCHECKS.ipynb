# %% [markdown]
# # Benchmarks

# %% [markdown]
# ## Initialize

# %%
#library(Rmisc)
library(dtplyr)
library(tidyverse)
library(glue)
library(arrow)
library(patchwork)
library(data.table)
library("jsonlite")
library(ggthemes)

# %%
if (grepl("sc", Sys.info()[["nodename"]], fixed=TRUE)) {
    base_path = "/sc-projects/sc-proj-ukb-cvd"
} else {
    base_path = "/data/analysis/ag-reils/ag-reils-shared/cardioRS"}
print(base_path)

project_label = "22_retina_phewas"
project_path = glue("{base_path}/results/projects/{project_label}")
figure_path = glue("{project_path}/figures")
output_path = glue("{project_path}/data")

experiment = '220812_test'
experiment_path = glue("{output_path}/{experiment}")
# Out:
# [1] "/sc-projects/sc-proj-ukb-cvd"

# %%
base_size = 8
title_size = 10
facet_size = 9
geom_text_size=3
theme_set(theme_classic(base_size = base_size) + 
          theme(strip.background = element_blank(), plot.title=element_text(size=title_size, hjust=0), 
                strip.text.x = element_text(size = facet_size),axis.title=element_text(size=10), axis.text=element_text(size=8, color="black"),
                legend.position="bottom", axis.line = element_line(size = 0.2), axis.ticks=element_line(size=0.2), panel.grid.major.y=element_line()))

# %%
colors_dict = read_json("colors.json")
color_map <- c(
    "Age+Sex" = colors_dict$pastel$red$mid,
    "Retina" = colors_dict$pastel$red$mid,
    "Age+Sex+Retina" = colors_dict$pastel$red$mid,
    'MultiTaskSurvivalTraining_None_InceptionResnetV2+MLP_Identity' = colors_dict$pastel$red$mid
    #"Identity(AgeSex)+MLP" = colors_dict$pastel$red$mid,
    #"Identity(Records)+MLP" = colors_dict$pastel$red$mid,
    #"GNN(Records)+MLP" = colors_dict$pastel$red$mid,
    #"Identity(AgeSex+Records)+MLP" = colors_dict$pastel$red$mid,
    #"GNN(AgeSex+Records)+MLP" = colors_dict$pastel$red$mid
)

# %%
endpoint_defs = arrow::read_feather(glue("{output_path}/phecode_defs_220306.feather")) %>% arrange(endpoint)
endpoints_md = fread(glue("{experiment_path}/endpoints.csv"), colClasses=c("phecode"="character"))
endpoints = sort(endpoints_md$endpoint)

# %%
endpoint_map = endpoint_defs$phecode_string
names(endpoint_map) =  endpoint_defs$endpoint
endpoint_order = (endpoint_defs %>% arrange(as.numeric(phecode)))$endpoint

# %%
endpoint_selection = c(
    # generally very important
    "phecode_202", # Diabetes mellitus
    "phecode_404", # Ischemic heart disease
    "phecode_404-1", # Myocardial infarction [Heart attack]
    "phecode_431-11", # Cerebral infarction [Ischemic stroke]
    "phecode_424", # Heart failure
    "OMOP_4306655", # All-Cause Death
    # also generally important and relevant
    #"phecode_440-3", # Pulmonary embolism
    #"phecode_468-1",	#Viral pneumonia
    "phecode_401",	#Hypertension"
    "phecode_460-2",	#Acute lower respiratory infection
    "phecode_468", # Pneumonia
    "phecode_474", # Chronic obstructive pulmonary disease [COPD]
    "phecode_542", # Chronic liver disease and sequelae
    "phecode_583", # Chronic kidney disease
    "phecode_328", # Dementias and cerebral degeneration
    
    
    # generally important and fun to check
    "phecode_164", # Anemia
   # "phecode_726-1", # Osteoporosis
    "phecode_286-2", #	Major depressive disorder
    "phecode_103", # Malignant neoplasm of the skin
    "phecode_101", # Malignant neoplasm of the digestive organs
    #"phecode_665", # Psoriasis
    "phecode_121", # Leukemia
    "phecode_705-1", # Rheumatoid arthritis
    
    
    # important for eye
    "phecode_371", # Cataract
   # "phecode_374-3", # Retinal vascular changes and occlusions
    "phecode_374-42", # Diabetic retinopathy
    "phecode_374-5", # Macular degeneration
    "phecode_375-1" # Glaucoma
    #"phecode_388" # Blindness and low vision
)

endpoints_common = c(
   'phecode_164', #Anemia
 'phecode_705-1', #Rheumatoid arthritis
 'phecode_328', #Dementias and cerebral degeneration
 'phecode_328-1', #Alzheimer's disease
 'phecode_401', #Hypertension
 'phecode_202', #Diabetes mellitus
 'phecode_416-21', #Atrial fibrillation
 'phecode_404-1', #Myocardial infarction [Heart attack]
 'phecode_424', #Heart failure
 'phecode_468', #Pneumonia
 'phecode_474', #Chronic obstructive pulmonary disease [COPD]
 'phecode_583', #Chronic kidney disease
 'OMOP_4306655' #All-Cause Death
    )
    
endpoints_cardio = c(
    'phecode_438-11',   #  "Abdominal aortic aneurysm",
    'phecode_440-3',#  "Pulmonary embolism", # intervention
    'phecode_413-21',#  "Aortic stenosis", # intervention
    'phecode_400'#  "Rheumatic fever and chronic rheumatic heart diseases",	
)

endpoints_eye= c(
    'phecode_374-5', #Macular degeneration
 'phecode_374-51', #Age-related macular degeneration
 'phecode_374-42', #Diabetic retinopathy
 'phecode_371', #Cataract
 'phecode_388', #Blindness and low vision
 'phecode_367-5', #Uveitis
 'phecode_389-1' #Ocular pain
)

# %%
endpoint_defs = endpoint_defs %>% 
    mutate(name = phecode_string) %>%
    mutate(name = 
           case_when( 
               phecode_string == "Myocardial infarction [Heart attack]"~"Myocardial infarction",
               phecode_string == "Cerebral infarction [Ischemic stroke]"~"Ischemic stroke",
               phecode_string == "Chronic obstructive pulmonary disease [COPD]"~"Chronic obstructive pulmonary disease",
               phecode_string == "Mitral valve insufficiency"~"Mitral insufficiency",
               phecode_string == "Parkinson's disease (Primary)"~"Parkinson's disease",
               phecode_string == "Suicide ideation and attempt or self harm"~"Suicide attempt",
               phecode_string == "Ischemic heart disease"~"Coronary heart disease",
               phecode_string == "Chronic kidney disease"~"Chronic kidney disease",
               phecode_string == "Rheumatic fever and chronic rheumatic heart diseases"~"Rheumatic heart disease",
               phecode_string == "Abdominal aortic aneurysm"~"Abdominal aortic aneurysm",
                  TRUE ~ name)
           )
            
endpoint_map = endpoint_defs$name
names(endpoint_map) =  endpoint_defs$endpoint
#endpoint_order = (endpoint_defs %>% arrange(as.numeric(phecode)))$endpoint
endpoint_order = endpoint_selection

# %% [markdown]
# # Load Benchmarks

# %%
#today = substr(Sys.time(), 0, 10) # YYYY-MM-DD
today = '221103'
name = glue("benchmarks_cindex_{today}")
benchmark_endpoints = arrow::read_feather(glue("{experiment_path}/{name}.feather")) %>% left_join(endpoints_md)
# Out:
# Joining, by = "endpoint"

# %%
benchmark_endpoints %>% group_by(endpoint, score) %>% summarise(cindex=mean(cindex)) %>% group_by(score) %>% summarise(mean(cindex)) %>% arrange(`mean(cindex)`)
# Out:
# `summarise()` has grouped output by 'endpoint'. You can override using the
# `.groups` argument.
#   score          mean(cindex)
# 1 Age+Sex        0.6043953
# 2 Retina         0.6069207
# 3 Age+Sex+Retina 0.6171583
# 4 SCORE2         0.6208000
# 5 SCORE2+Retina  0.6256793
# 6 ASCVD          0.6265802
# 7 ASCVD+Retina   0.6271062
# 8 QRISK3+Retina  0.6376704
# 9 QRISK3         0.6383278

# %%
endpoints_sorted = (benchmark_endpoints %>% 
    filter(score == "Age+Sex+Retina") %>% 
    group_by(endpoint, score) %>% 
    summarise(cindex=mean(cindex, na.rm=TRUE)) %>% 
    arrange(cindex) %>% ungroup())$endpoint
# Out:
# `summarise()` has grouped output by 'endpoint'. You can override using the
# `.groups` argument.

# %%
categories_sorted = (endpoint_defs %>% distinct(phecode_category))$phecode_category

# %%
benchmark_endpoints
# Out:
#        endpoint       score
# 1      OMOP_4306655   Age+Sex
# 2      OMOP_4306655   Retina
# 3      OMOP_4306655   Age+Sex+Retina
# 4      OMOP_4306655   SCORE2
# 5      OMOP_4306655   SCORE2+Retina
# 6      OMOP_4306655   ASCVD
# 7      OMOP_4306655   ASCVD+Retina
# 8      OMOP_4306655   QRISK3
# 9      OMOP_4306655   QRISK3+Retina
# 10     phecode_002    Age+Sex
# 11     phecode_002    Retina
# 12     phecode_002    Age+Sex+Retina
# 13     phecode_002    SCORE2
# 14     phecode_002    SCORE2+Retina
# 15     phecode_002    ASCVD
# 16     phecode_002    ASCVD+Retina
# 17     phecode_002    QRISK3
# 18     phecode_002    QRISK3+Retina
# 19     phecode_002-1  Age+Sex
# 20     phecode_002-1  Retina
# 21     phecode_002-1  Age+Sex+Retina
# 22     phecode_002-1  SCORE2
# 23     phecode_002-1  SCORE2+Retina
# 24     phecode_002-1  ASCVD
# 25     phecode_002-1  ASCVD+Retina
# 26     phecode_002-1  QRISK3
# 27     phecode_002-1  QRISK3+Retina
# 28     phecode_003    Age+Sex
# 29     phecode_003    Retina
# 30     phecode_003    Age+Sex+Retina
# ⋮      ⋮              ⋮
# 569077 phecode_977-7  ASCVD+Retina
# 569078 phecode_977-7  QRISK3
# 569079 phecode_977-7  QRISK3+Retina
# 569080 phecode_977-71 Age+Sex
# 569081 phecode_977-71 Retina
# 569082 phecode_977-71 Age+Sex+Retina
# 569083 phecode_977-71 SCORE2
# 569084 phecode_977-71 SCORE2+Retina
# 569085 phecode_977-71 ASCVD
# 569086 phecode_977-71 ASCVD+Retina
# 569087 phecode_977-71 QRISK3
# 569088 phecode_977-71 QRISK3+Retina
# 569089 phecode_977-72 Age+Sex
# 569090 phecode_977-72 Retina
# 569091 phecode_977-72 Age+Sex+Retina
# 569092 phecode_977-72 SCORE2
# 569093 phecode_977-72 SCORE2+Retina
# 569094 phecode_977-72 ASCVD
# 569095 phecode_977-72 ASCVD+Retina
# 569096 phecode_977-72 QRISK3
# 569097 phecode_977-72 QRISK3+Retina
# 569098 phecode_979    Age+Sex
# 569099 phecode_979    Retina
# 569100 phecode_979    Age+Sex+Retina
# 569101 phecode_979    SCORE2
# 569102 phecode_979    SCORE2+Retina
# 569103 phecode_979    ASCVD
# 569104 phecode_979    ASCVD+Retina
# 569105 phecode_979    QRISK3
# 569106 phecode_979    QRISK3+Retina
#        model                                                       iteration
# 1      ImageTraining_[]_ConvNeXt_MLPHead_predictions_cropratio0.66 49
# 2      ImageTraining_[]_ConvNeXt_MLPHead_predictions_cropratio0.66 49
# 3      ImageTraining_[]_ConvNeXt_MLPHead_predictions_cropratio0.66 49
# 4      ImageTraining_[]_ConvNeXt_MLPHead_predictions_cropratio0.66 49
# 5      ImageTraining_[]_ConvNeXt_MLPHead_predictions_cropratio0.66 49
# 6      ImageTraining_[]_ConvNeXt_MLPHead_predictions_cropratio0.66 49
# 7      ImageTraining_[]_ConvNeXt_MLPHead_predictions_cropratio0.66 49
# 8      ImageTraining_[]_ConvNeXt_MLPHead_predictions_cropratio0.66 49
# 9      ImageTraining_[]_ConvNeXt_MLPHead_predictions_cropratio0.66 49
# 10     ImageTraining_[]_ConvNeXt_MLPHead_predictions_cropratio0.66 49
# 11     ImageTraining_[]_ConvNeXt_MLPHead_predictions_cropratio0.66 49
# 12     ImageTraining_[]_ConvNeXt_MLPHead_predictions_cropratio0.66 49
# 13     ImageTraining_[]_ConvNeXt_MLPHead_predictions_cropratio0.66 49
# 14     ImageTraining_[]_ConvNeXt_MLPHead_predictions_cropratio0.66 49
# 15     ImageTraining_[]_ConvNeXt_MLPHead_predictions_cropratio0.66 49
# 16     ImageTraining_[]_ConvNeXt_MLPHead_predictions_cropratio0.66 49
# 17     ImageTraining_[]_ConvNeXt_MLPHead_predictions_cropratio0.66 49
# 18     ImageTraining_[]_ConvNeXt_MLPHead_predictions_cropratio0.66 49
# 19     ImageTraining_[]_ConvNeXt_MLPHead_predictions_cropratio0.66 49
# 20     ImageTraining_[]_ConvNeXt_MLPHead_predictions_cropratio0.66 49
# 21     ImageTraining_[]_ConvNeXt_MLPHead_predictions_cropratio0.66 49
# 22     ImageTraining_[]_ConvNeXt_MLPHead_predictions_cropratio0.66 49
# 23     ImageTraining_[]_ConvNeXt_MLPHead_predictions_cropratio0.66 49
# 24     ImageTraining_[]_ConvNeXt_MLPHead_predictions_cropratio0.66 49
# 25     ImageTraining_[]_ConvNeXt_MLPHead_predictions_cropratio0.66 49
# 26     ImageTraining_[]_ConvNeXt_MLPHead_predictions_cropratio0.66 49
# 27     ImageTraining_[]_ConvNeXt_MLPHead_predictions_cropratio0.66 49
# 28     ImageTraining_[]_ConvNeXt_MLPHead_predictions_cropratio0.66 49
# 29     ImageTraining_[]_ConvNeXt_MLPHead_predictions_cropratio0.66 49
# 30     ImageTraining_[]_ConvNeXt_MLPHead_predictions_cropratio0.66 49
# ⋮      ⋮                                                           ⋮
# 569077 ImageTraining_[]_ConvNeXt_MLPHead_predictions_cropratio0.66 14
# 569078 ImageTraining_[]_ConvNeXt_MLPHead_predictions_cropratio0.66 14
# 569079 ImageTraining_[]_ConvNeXt_MLPHead_predictions_cropratio0.66 14
# 569080 ImageTraining_[]_ConvNeXt_MLPHead_predictions_cropratio0.66 14
# 569081 ImageTraining_[]_ConvNeXt_MLPHead_predictions_cropratio0.66 14
# 569082 ImageTraining_[]_ConvNeXt_MLPHead_predictions_cropratio0.66 14
# 569083 ImageTraining_[]_ConvNeXt_MLPHead_predictions_cropratio0.66 14
# 569084 ImageTraining_[]_ConvNeXt_MLPHead_predictions_cropratio0.66 14
# 569085 ImageTraining_[]_ConvNeXt_MLPHead_predictions_cropratio0.66 14
# 569086 ImageTraining_[]_ConvNeXt_MLPHead_predictions_cropratio0.66 14
# 569087 ImageTraining_[]_ConvNeXt_MLPHead_predictions_cropratio0.66 14
# 569088 ImageTraining_[]_ConvNeXt_MLPHead_predictions_cropratio0.66 14
# 569089 ImageTraining_[]_ConvNeXt_MLPHead_predictions_cropratio0.66 14
# 569090 ImageTraining_[]_ConvNeXt_MLPHead_predictions_cropratio0.66 14
# 569091 ImageTraining_[]_ConvNeXt_MLPHead_predictions_cropratio0.66 14
# 569092 ImageTraining_[]_ConvNeXt_MLPHead_predictions_cropratio0.66 14
# 569093 ImageTraining_[]_ConvNeXt_MLPHead_predictions_cropratio0.66 14
# 569094 ImageTraining_[]_ConvNeXt_MLPHead_predictions_cropratio0.66 14
# 569095 ImageTraining_[]_ConvNeXt_MLPHead_predictions_cropratio0.66 14
# 569096 ImageTraining_[]_ConvNeXt_MLPHead_predictions_cropratio0.66 14
# 569097 ImageTraining_[]_ConvNeXt_MLPHead_predictions_cropratio0.66 14
# 569098 ImageTraining_[]_ConvNeXt_MLPHead_predictions_cropratio0.66 14
# 569099 ImageTraining_[]_ConvNeXt_MLPHead_predictions_cropratio0.66 14
# 569100 ImageTraining_[]_ConvNeXt_MLPHead_predictions_cropratio0.66 14
# 569101 ImageTraining_[]_ConvNeXt_MLPHead_predictions_cropratio0.66 14
# 569102 ImageTraining_[]_ConvNeXt_MLPHead_predictions_cropratio0.66 14
# 569103 ImageTraining_[]_ConvNeXt_MLPHead_predictions_cropratio0.66 14
# 569104 ImageTraining_[]_ConvNeXt_MLPHead_predictions_cropratio0.66 14
# 569105 ImageTraining_[]_ConvNeXt_MLPHead_predictions_cropratio0.66 14
# 569106 ImageTraining_[]_ConvNeXt_MLPHead_predictions_cropratio0.66 14
#        time cindex    V1   eligable n    freq        phecode
# 1      10   0.7395676 0    61256    3490 0.056974011 4306655
# 2      10   0.7442909 0    61256    3490 0.056974011 4306655
# 3      10   0.7517869 0    61256    3490 0.056974011 4306655
# 4      10   0.7538439 0    61256    3490 0.056974011 4306655
# 5      10   0.7605750 0    61256    3490 0.056974011 4306655
# 6      10   0.7529524 0    61256    3490 0.056974011 4306655
# 7      10   0.7580850 0    61256    3490 0.056974011 4306655
# 8      10   0.7651111 0    61256    3490 0.056974011 4306655
# 9      10   0.7682256 0    61256    3490 0.056974011 4306655
# 10     10   0.6732771 1    60945     658 0.010796620 002
# 11     10   0.6968023 1    60945     658 0.010796620 002
# 12     10   0.6275788 1    60945     658 0.010796620 002
# 13     10   0.7095215 1    60945     658 0.010796620 002
# 14     10   0.6418209 1    60945     658 0.010796620 002
# 15     10   0.7127690 1    60945     658 0.010796620 002
# 16     10   0.6891738 1    60945     658 0.010796620 002
# 17     10   0.7000510 1    60945     658 0.010796620 002
# 18     10   0.6704542 1    60945     658 0.010796620 002
# 19     10   0.6516687 2    61010     486 0.007965907 002.1
# 20     10   0.6395226 2    61010     486 0.007965907 002.1
# 21     10   0.5693595 2    61010     486 0.007965907 002.1
# 22     10   0.6037718 2    61010     486 0.007965907 002.1
# 23     10   0.5926169 2    61010     486 0.007965907 002.1
# 24     10   0.5908248 2    61010     486 0.007965907 002.1
# 25     10   0.5936530 2    61010     486 0.007965907 002.1
# 26     10   0.6055739 2    61010     486 0.007965907 002.1
# 27     10   0.5972201 2    61010     486 0.007965907 002.1
# 28     10   0.6083610 3    60757     959 0.015784189 003
# 29     10   0.5853316 3    60757     959 0.015784189 003
# 30     10   0.6017449 3    60757     959 0.015784189 003
# ⋮      ⋮    ⋮         ⋮    ⋮        ⋮    ⋮           ⋮
# 569077 10   0.8260310 1166 60032    2231 0.037163513 977.7
# 569078 10   0.8357864 1166 60032    2231 0.037163513 977.7
# 569079 10   0.8401627 1166 60032    2231 0.037163513 977.7
# 569080 10   0.5357068 1167 60936     472 0.007745832 977.71
# 569081 10   0.6782316 1167 60936     472 0.007745832 977.71
# 569082 10   0.6805027 1167 60936     472 0.007745832 977.71
# 569083 10   0.7039452 1167 60936     472 0.007745832 977.71
# 569084 10   0.7266060 1167 60936     472 0.007745832 977.71
# 569085 10   0.8754838 1167 60936     472 0.007745832 977.71
# 569086 10   0.8829521 1167 60936     472 0.007745832 977.71
# 569087 10   0.8973625 1167 60936     472 0.007745832 977.71
# 569088 10   0.8991761 1167 60936     472 0.007745832 977.71
# 569089 10   0.6458813 1168 60207    2148 0.035676915 977.72
# 569090 10   0.7621303 1168 60207    2148 0.035676915 977.72
# 569091 10   0.7722323 1168 60207    2148 0.035676915 977.72
# 569092 10   0.6904833 1168 60207    2148 0.035676915 977.72
# 569093 10   0.7752634 1168 60207    2148 0.035676915 977.72
# 569094 10   0.8421067 1168 60207    2148 0.035676915 977.72
# 569095 10   0.8489094 1168 60207    2148 0.035676915 977.72
# 569096 10   0.8710989 1168 60207    2148 0.035676915 977.72
# 569097 10   0.8726318 1168 60207    2148 0.035676915 977.72
# 569098 10   0.5822061 1169 61159     158 0.002583430 979
# 569099 10   0.5516404 1169 61159     158 0.002583430 979
# 569100 10   0.4540506 1169 61159     158 0.002583430 979
# 569101 10   0.5817396 1169 61159     158 0.002583430 979
# 569102 10   0.4941032 1169 61159     158 0.002583430 979
# 569103 10   0.5134418 1169 61159     158 0.002583430 979
# 569104 10   0.4771307 1169 61159     158 0.002583430 979
# 569105 10   0.4715592 1169 61159     158 0.002583430 979
# 569106 10   0.4442024 1169 61159     158 0.002583430 979
#        phecode_string
# 1      All-Cause Death
# 2      All-Cause Death
# 3      All-Cause Death
# 4      All-Cause Death
# 5      All-Cause Death
# 6      All-Cause Death
# 7      All-Cause Death
# 8      All-Cause Death
# 9      All-Cause Death
# 10     Staphylococcus
# 11     Staphylococcus
# 12     Staphylococcus
# 13     Staphylococcus
# 14     Staphylococcus
# 15     Staphylococcus
# 16     Staphylococcus
# 17     Staphylococcus
# 18     Staphylococcus
# 19     Staphylococcus aureus
# 20     Staphylococcus aureus
# 21     Staphylococcus aureus
# 22     Staphylococcus aureus
# 23     Staphylococcus aureus
# 24     Staphylococcus aureus
# 25     Staphylococcus aureus
# 26     Staphylococcus aureus
# 27     Staphylococcus aureus
# 28     Escherichia coli
# 29     Escherichia coli
# 30     Escherichia coli
# ⋮      ⋮
# 569077 Long term (current) use of insulin or oral hypoglycemic drugs
# 569078 Long term (current) use of insulin or oral hypoglycemic drugs
# 569079 Long term (current) use of insulin or oral hypoglycemic drugs
# 569080 Long term (current) use of insulin
# 569081 Long term (current) use of insulin
# 569082 Long term (current) use of insulin
# 569083 Long term (current) use of insulin
# 569084 Long term (current) use of insulin
# 569085 Long term (current) use of insulin
# 569086 Long term (current) use of insulin
# 569087 Long term (current) use of insulin
# 569088 Long term (current) use of insulin
# 569089 Long term (current) use of oral hypoglycemic drugs
# 569090 Long term (current) use of oral hypoglycemic drugs
# 569091 Long term (current) use of oral hypoglycemic drugs
# 569092 Long term (current) use of oral hypoglycemic drugs
# 569093 Long term (current) use of oral hypoglycemic drugs
# 569094 Long term (current) use of oral hypoglycemic drugs
# 569095 Long term (current) use of oral hypoglycemic drugs
# 569096 Long term (current) use of oral hypoglycemic drugs
# 569097 Long term (current) use of oral hypoglycemic drugs
# 569098 Transplated organ
# 569099 Transplated organ
# 569100 Transplated organ
# 569101 Transplated organ
# 569102 Transplated organ
# 569103 Transplated organ
# 569104 Transplated organ
# 569105 Transplated organ
# 569106 Transplated organ
#        phecode_category sex  ICD10_only phecode_top leaf
# 1      Death            Both NA         NA          NA
# 2      Death            Both NA         NA          NA
# 3      Death            Both NA         NA          NA
# 4      Death            Both NA         NA          NA
# 5      Death            Both NA         NA          NA
# 6      Death            Both NA         NA          NA
# 7      Death            Both NA         NA          NA
# 8      Death            Both NA         NA          NA
# 9      Death            Both NA         NA          NA
# 10     ID               Both  0          2           0
# 11     ID               Both  0          2           0
# 12     ID               Both  0          2           0
# 13     ID               Both  0          2           0
# 14     ID               Both  0          2           0
# 15     ID               Both  0          2           0
# 16     ID               Both  0          2           0
# 17     ID               Both  0          2           0
# 18     ID               Both  0          2           0
# 19     ID               Both  0          2           1
# 20     ID               Both  0          2           1
# 21     ID               Both  0          2           1
# 22     ID               Both  0          2           1
# 23     ID               Both  0          2           1
# 24     ID               Both  0          2           1
# 25     ID               Both  0          2           1
# 26     ID               Both  0          2           1
# 27     ID               Both  0          2           1
# 28     ID               Both  0          3           1
# 29     ID               Both  0          3           1
# 30     ID               Both  0          3           1
# ⋮      ⋮                ⋮    ⋮          ⋮           ⋮
# 569077 Rx               Both 0          977         0
# 569078 Rx               Both 0          977         0
# 569079 Rx               Both 0          977         0
# 569080 Rx               Both 0          977         1
# 569081 Rx               Both 0          977         1
# 569082 Rx               Both 0          977         1
# 569083 Rx               Both 0          977         1
# 569084 Rx               Both 0          977         1
# 569085 Rx               Both 0          977         1
# 569086 Rx               Both 0          977         1
# 569087 Rx               Both 0          977         1
# 569088 Rx               Both 0          977         1
# 569089 Rx               Both 0          977         1
# 569090 Rx               Both 0          977         1
# 569091 Rx               Both 0          977         1
# 569092 Rx               Both 0          977         1
# 569093 Rx               Both 0          977         1
# 569094 Rx               Both 0          977         1
# 569095 Rx               Both 0          977         1
# 569096 Rx               Both 0          977         1
# 569097 Rx               Both 0          977         1
# 569098 Stat             Both 0          979         0
# 569099 Stat             Both 0          979         0
# 569100 Stat             Both 0          979         0
# 569101 Stat             Both 0          979         0
# 569102 Stat             Both 0          979         0
# 569103 Stat             Both 0          979         0
# 569104 Stat             Both 0          979         0
# 569105 Stat             Both 0          979         0
# 569106 Stat             Both 0          979         0

# %% [markdown]
# benchmark_endpoints## General Performance

# %%
library(ggtext)
library(ggdist)

scores_plot = c("Age+Sex", "Age+Sex+Retina")#, "AgeSexRetina")

temp = benchmark_endpoints %>% 
    filter(score %in% scores_plot) %>% 
    mutate(score = factor(score, levels=scores_plot)) %>%
    mutate(endpoint = factor(endpoint, levels=endpoints_sorted)) %>%
    ungroup() %>%
    pivot_wider(names_from=score, values_from=cindex) %>% 
    mutate(id = row_number()) %>%
    mutate(delta = `Age+Sex+Retina`-`Age+Sex`) %>%
    group_by(endpoint, phecode_string, freq, phecode_category) %>%
    median_qi(delta) %>%
    mutate(pos = case_when(delta>=0 ~ "pos", delta < 0 ~"neg")) %>%
    mutate(endpoint = fct_reorder(endpoint, delta)) %>%
    mutate(highlight = case_when(endpoint %in% endpoint_selection ~ "YES", TRUE ~ "NO")) %>%# %>% filter(endpoint %in% endpoint_sample)
    mutate(phecode_category = factor(phecode_category, levels=categories_sorted))

endpoint_order = (temp %>% arrange(delta))$endpoint
#%>% #mutate(endpoint = factor(endpoint, levels=endpoint_order)) 
temp = temp  %>% ungroup() %>% arrange(endpoint) %>% group_by(phecode_category) #%>% mutate(endpoint = row_number())

# %%
temp %>%  %>% head()
# Out:
#   endpoint       phecode_string                       freq
# 1 phecode_209-1  Pituitary hyperfunction              0.001667375
# 2 phecode_721-4  Calcium deposits in tendon and bursa 0.002287881
# 3 phecode_367-21 Corneal ulcer                        0.001652703
# 4 phecode_170-19 Neutropenia NOS                      0.004619467
# 5 phecode_621    Endometrial hyperplasia              0.003291957
# 6 phecode_179-9  Immunodeficiency NOS                 0.001879484
#   phecode_category delta      .lower     .upper       .width .point .interval
# 1 Endo             -0.6034543 -0.7690935 -0.044122726 0.95   median qi
# 2 Musc/Skel        -0.2993190 -0.4370733 -0.047849977 0.95   median qi
# 3 Eye              -0.2539865 -0.4087497 -0.036825249 0.95   median qi
# 4 Blood            -0.2131754 -0.3081901 -0.064206385 0.95   median qi
# 5 Genitourinary    -0.1717609 -0.3741748  0.072306325 0.95   median qi
# 6 Blood            -0.1705765 -0.3583009 -0.001694656 0.95   median qi
#   pos highlight
# 1 neg NO
# 2 neg NO
# 3 neg NO
# 4 neg NO
# 5 neg NO
# 6 neg NO

# %%
benchmark_endpoints = benchmark_endpoints %>%
    filter(model == glue("ImageTraining_[]_ConvNeXt_MLPHead_predictions_cropratio{crop_ratio}"))

# %%
x = benchmark_endpoints %>% group_by(endpoint, score) %>%
                        summarise(cindex=mean(cindex)) %>% 
                        select(endpoint, score, cindex) %>% 
                        filter(score=='Age+Sex') %>% 
                        left_join(by='endpoint', temp)
x %>% head()
# Out:
# `summarise()` has grouped output by 'endpoint'. You can override using the
# `.groups` argument.
#   endpoint      score   cindex    phecode_string        freq
# 1 OMOP_4306655  Age+Sex 0.7428650 All-Cause Death       0.056974011
# 2 phecode_002   Age+Sex 0.6607751 Staphylococcus        0.010796620
# 3 phecode_002-1 Age+Sex 0.6522515 Staphylococcus aureus 0.007965907
# 4 phecode_003   Age+Sex 0.6133523 Escherichia coli      0.015784189
# 5 phecode_004   Age+Sex 0.5140085 Streptococcus         0.008153968
# 6 phecode_005   Age+Sex 0.2158769 Mycobacteria          0.001855531
#   phecode_category delta        .lower      .upper       .width .point
# 1 Death             0.006304892 -0.01132576  0.023608464 0.95   median
# 2 ID               -0.049669291 -0.09144558 -0.008650644 0.95   median
# 3 ID               -0.070450138 -0.14101327 -0.015134211 0.95   median
# 4 ID                0.027458275 -0.01285415  0.058417084 0.95   median
# 5 ID               -0.003166362 -0.06269310  0.067323834 0.95   median
# 6 ID                0.486541152  0.04988126  0.606981854 0.95   median
#   .interval pos highlight
# 1 qi        pos YES
# 2 qi        neg NO
# 3 qi        neg NO
# 4 qi        pos NO
# 5 qi        neg NO
# 6 qi        pos NO

# %%
# FREQ VS DELTA

# %%
plot_width = 6; plot_height=4; plot_res = 320
options(repr.plot.width = plot_width, repr.plot.height = plot_height, repr.plot.res=plot_res)

ggplot(x) +
  geom_point(aes(x=log(freq), y=delta, color=cindex), size=0.5, alpha=1) +
    scale_color_gradient(low = "yellow", high = "red") +
  labs(y="C-Index Delta (Age+Sex vs. Age+Sex+Retina)", x="log(Endpoint Frequency)")
# Out:
# Warning message:
# “Removed 1 rows containing missing values (geom_point).”
# plot without title

# %%
ggplot(x) +
  geom_point(aes(x=log(freq), y=cindex), size=0.5, alpha=1) +
#     scale_color_gradient(low = "yellow", high = "red") +
  labs(y="C-Index Age+Sex", x="log(Endpoint Frequency)")
# Out:
# Warning message:
# “Removed 1 rows containing missing values (geom_point).”
# plot without title

# %% [markdown]
# # EID PROBLEM!

# %%
import pandas as pd
# Out:
# Error in parse(text = x, srcfile = src): <text>:1:8: unexpected symbol
# 1: import pandas
#            ^
# Traceback:
